# %% [markdown]
# ####Mount Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# current_dir has the name of the folder where the project is.
# (you can change it to experiment, just make sure to change in subsequent notebooks as well :)

# %%
current_dir = 'Home Credit_Kaggle'

# set the project folder as current working directory
import os
complete_path = os.path.join('/content/drive/My Drive/Colab Notebooks/',current_dir)
os.chdir(complete_path)

# %%
# verify the current working directory
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Home Credit_Kaggle'

# %% [markdown]
# ####Downloading the data from Kaggle

# %% [markdown]
# Upload the kaggle.json file in the project directory and then run below command, to copy it to root directory. In case .kaggle folder is not present in root directory, you might need to install kaggle api using below command.
#
# How to get kaggle.json and what is kaggle API?
# https://github.com/Kaggle/kaggle-api

# %%
# install kaggle api
# !pip3 install kaggle

# %%
# if .kaggle folder is not present then create .kaggle folder
kag_path = '/root/.kaggle'
if not os.path.isdir(kag_path):
  os.mkdir(kag_path)

# copy kaggle.json file
# !cp kaggle.json /root/.kaggle/kaggle.json

# %%
# make sure it was copied
# !ls /root/.kaggle
# Out:
# kaggle.json

# %% [markdown]
# Voila! Now use below commands to first create a folder named 'data' and then set it as current directory.

# %%
data_path = os.path.join(complete_path,'data')
if not os.path.isdir(data_path):
  os.mkdir(data_path)

os.chdir(data_path)

# %%
# verify the current working directory
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Home Credit_Kaggle/data'

# %% [markdown]
# Now use kaggle api which will use kaggle json to download data to the current directory, which is 'data' folder.

# %%
# !kaggle competitions download -c home-credit-default-risk
# Out:
# ...
#  89% 97.0M/109M [00:00<00:00, 135MB/s]
# 100% 109M/109M [00:00<00:00, 131MB/s]
# ...
# 100% 96.7M/96.7M [00:00<00:00, 129MB/s]
#
# ...
#   0% 0.00/36.5k [00:00<?, ?B/s]
# 100% 36.5k/36.5k [00:00<00:00, 228kB/s]
# ...
#  89% 68.0M/76.3M [00:00<00:00, 135MB/s]
# 100% 76.3M/76.3M [00:00<00:00, 130MB/s]
# ...
#  97% 264M/271M [00:02<00:00, 116MB/s]
# 100% 271M/271M [00:02<00:00, 114MB/s]
# ...
#  98% 36.0M/36.8M [00:00<00:00, 38.7MB/s]
# 100% 36.8M/36.8M [00:01<00:00, 37.5MB/s]
# ...
#  88% 50.0M/56.8M [00:00<00:00, 103MB/s]
# 100% 56.8M/56.8M [00:00<00:00, 96.5MB/s]
# ...
#  97% 35.0M/36.1M [00:01<00:00, 15.9MB/s]
# 100% 36.1M/36.1M [00:01<00:00, 25.0MB/s]
# ...
#   0% 0.00/5.81M [00:00<?, ?B/s]
# 100% 5.81M/5.81M [00:00<00:00, 53.1MB/s]
# ...
#   0% 0.00/524k [00:00<?, ?B/s]
# 100% 524k/524k [00:00<00:00, 33.7MB/s]
